# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
data = pd.read_csv(r"Sentiment_data.csv")
data.head()
# Out:
#   Cust_name              Cust_email  \
# 0     Jared   jared8917@example.com
# 1     Marie   marie2554@example.com
# 2    Elijah  elijah1499@example.com
# 3    Sheryl  sheryl5700@example.com
# 4    Jeremy  jeremy6170@example.com
#
#                                             Feedback        Date  Care_Taker  \
# 0  beautiful accomodations stayed hotel santa mar...  2024-10-27      Jarvis
# 1  great hotel great location hotel located la ra...  2018-11-21      Malone
# 2  beautiful hotel great location like beautifull...  2023-06-18     Barrera
# 3  great deal waikiki trip hawaii outrigger luana...  2009-07-21  Montgomery
# 4  choose airport hotel busy triparound australia...  2023-08-05     Houston
#
#     Emp_id  Age     Contact     Department  Customer Stay Duration (hrs)  \
# 0  EMP2668   25  6387855360    Maintenance                           3.1
# 1  EMP2743   25  6413355279           Food                           4.3
# ...

# %% [markdown]
# ## Knowing Dataset

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 18 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Cust_name                     10000 non-null  object
#  1   Cust_email                    10000 non-null  object
#  2   Feedback                      10000 non-null  object
#  3   Date                          10000 non-null  object
#  4   Care_Taker                    10000 non-null  object
#  5   Emp_id                        10000 non-null  object
#  6   Age                           10000 non-null  int64
#  7   Contact                       10000 non-null  int64
#  8   Department                    10000 non-null  object
#  9   Customer Stay Duration (hrs)  10000 non-null  float64
#  10  Customer_N_visit              10000 non-null  int64
#  11  Cust amount to be paid        10000 non-null  float64
# ...

# %%
data.describe().drop('Contact', axis = 1)
# Out:
#                 Age  Customer Stay Duration (hrs)  Customer_N_visit  \
# count  10000.000000                  10000.000000      10000.000000
# mean      54.840100                      5.503210          5.493800
# std       20.478415                      2.593955          2.861639
# min       20.000000                      1.000000          1.000000
# 25%       37.000000                      3.200000          3.000000
# 50%       55.000000                      5.500000          5.000000
# 75%       73.000000                      7.700000          8.000000
# max       90.000000                     10.000000         10.000000
#
#        Cust amount to be paid           Nps
# count            10000.000000  10000.000000
# mean               250.797742      0.302600
# std                144.751139     57.638167
# min                  0.060000   -100.000000
# 25%                124.970000    -50.000000
# 50%                251.780000      1.000000
# ...

# %%
# Distribution of Age

plt.hist(data['Age'], bins=30, edgecolor = 'w')
plt.xlabel("Age")
plt.title("Distribution of age")
plt.show()

# %%
data.columns
# Out:
# Index(['Cust_name', 'Cust_email', 'Feedback', 'Date', 'Care_Taker', 'Emp_id',
#        'Age', 'Contact', 'Department', 'Customer Stay Duration (hrs)',
#        'Customer_N_visit', 'Cust amount to be paid', 'Nps', 'Dining',
#        'Room Preference', 'Sport Activities', 'Wellness', 'Pricing'],
#       dtype='object')

# %%
cat_cols = ['Department','Dining', 'Room Preference', 'Sport Activities', 'Wellness', 'Pricing']

# %%
for i in cat_cols:
    sns.barplot(x = data[i].value_counts().values, y =data[i].value_counts().index )
    plt.title('Distribution of '+ i)
    plt.show()

# %%
print("Average Length of feedback")
ls = [len(i.split(' ')) for i in data.Feedback]
sum(ls)/len(ls)

print("Maximum Length of feedback")
max(ls)
# Out:
# Average Length of feedback
# Maximum Length of feedback
# 1933
