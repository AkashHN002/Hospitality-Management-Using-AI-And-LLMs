# %%
import os

# %%
# %pwd
# Out:
# 'd:\\Projects\\SpringBoard_Internship\\LLM_Internship\\Analysis'

# %%
os.chdir("../")

# %%
# %pwd
# Out:
# 'd:\\Projects\\SpringBoard_Internship\\LLM_Internship'

# %%
import pandas as pd
import random
from sklearn.metrics.pairwise import cosine_similarity

# %%
data = pd.read_csv(r"Notebook/Sentiment_data.csv")

# %%
user_id = ["User_0"+str(i)  for i in range(1,10001)]

# %%
if "User_ID" not in data.columns:
    columns = ["User_ID"]+list(data.columns)
    data["User_ID"] = user_id
data_new = data[columns]
data_new
# Out:
#           User_ID Cust_name              Cust_email  \
# 0         User_01     Jared   jared1149@example.com
# 1         User_02     Marie   marie5383@example.com
# 2         User_03    Elijah  elijah3812@example.com
# 3         User_04    Sheryl  sheryl5962@example.com
# 4         User_05    Jeremy  jeremy1802@example.com
# ...           ...       ...                     ...
# 9995   User_09996    Janice  janice4931@example.com
# 9996   User_09997    Sheryl  sheryl5678@example.com
# 9997   User_09998     Bryan   bryan4564@example.com
# 9998   User_09999    Olivia  olivia5882@example.com
# 9999  User_010000     Malik   malik8982@example.com
#
#                                                Feedback        Date  \
# 0     beautiful accomodations stayed hotel santa mar...  2020-02-04
# 1     great hotel great location hotel located la ra...  2009-07-07
# 2     beautiful hotel great location like beautifull...  2013-06-20
# 3     great deal waikiki trip hawaii outrigger luana...  2019-12-17
# 4     choose airport hotel busy triparound australia...  2022-10-22
# ...                                                 ...         ...
# 9995  absolutely charming, co-worker recently spent ...  2016-10-15
# 9996  honest review arrived hotel midnight welcomed ...  2017-06-21
# 9997  not believe bad reviews hotel excellent, staye...  2006-11-18
# 9998  fantastic hotel stayed hotel october 12 octobe...  2010-04-17
# 9999  location actually stayed 4 nights april weddin...  2014-04-03
#
#       Care_Taker   Emp_id  Age     Contact        Department  \
# 0         Jarvis  EMP1581   29  8197691703        E-commerce
# 1         Malone  EMP2127   85  7386609540       Maintenance
# 2        Barrera  EMP2121   51  9355114579  Customer Service
# 3     Montgomery  EMP1000   86  8261513132           Laundry
# 4        Houston  EMP2578   28  9983623309       Photography
# ...          ...      ...  ...         ...               ...
# 9995     Bennett  EMP1165   51  6438973135               Gym
# 9996     Padilla  EMP1363   28  8274481104       Hospitality
# 9997       Cross  EMP2950   48  9410306199        E-commerce
# 9998     Simpson  EMP2048   72   832461243       Advertising
# 9999      Madden  EMP1393   39  7660212569               Gym
#
#       Customer Stay Duration (hrs)  Customer_N_visit  Cust amount to be paid  \
# 0                              8.0                 2                  389.17
# 1                              3.7                 9                  464.56
# 2                              8.4                 4                  252.29
# 3                              3.4                 7                  128.18
# 4                              9.9                10                   90.48
# ...                            ...               ...                     ...
# 9995                           9.5                 3                   62.75
# 9996                           1.1                10                   46.40
# 9997                           1.4                10                  374.98
# 9998                           8.4                 7                  426.01
# 9999                           4.5                 4                  354.30
#
#       Nps          Dining Room Preference Sport Activities  \
# 0       2  Non-Vegetarion            Twin           Runnin
# 1      19  Non-Vegetarion            King             Golf
# 2      21  Non-Vegetarion            King         Aerobics
# 3      50  Non-Vegetarion          Family      Gym Workout
# 4      29           Vegan           Suite     RugbyCycling
# ...   ...             ...             ...              ...
# 9995   77           Vegan            King       Volleyball
# 9996  -70  Non-Vegetarion          Family       Basketball
# 9997   80  Non-Vegetarion          Double             Golf
# 9998   22       Vegetaion           Suite             Yoga
# 9999   70  Non-Vegetarion            Twin           Tennis
#
#                   Wellness            Pricing
# 0            Yoga Sessions      Package deals
# 1           Herbal Therapy    Weekly discount
# 2              Body Scrubs  Last-minute deals
# 3     Skin Care Treatments     Kids stay free
# 4               Steam Room             Budget
# ...                    ...                ...
# 9995               Facials          Mid-range
# 9996    Meditation Classes    Weekly discount
# 9997     Beauty Treatments          Mid-range
# 9998       Fitness Classes   Senior discounts
# 9999       Fitness Classes      All-inclusive
#
# [10000 rows x 19 columns]

# %%
data_new.to_csv(r"Notebook/Sentiment.csv")

# %%
activities = {
        'amenities': ['pool', 'spa', 'gym', 'tennis_court', 'business_center'],
        'dining': ['main_restaurant', 'cafe', 'bar', 'room_service', 'buffet'],
        'activities': ['city_tour', 'beach_activity', 'cooking_class', 'yoga', 'golf']
}

# %%
def getUserData(data):
    user_data = []
    for id in data.User_ID:
        for i in range(random.randint(10,20)):
            category = random.choice(list(activities.keys()))
            activity = random.choice(activities[category])
            rating = random.randint(1, 5)
            time_spent = random.randint(30, 180)
            user_data.append({
                "User_ID":id,
                "Category":category,
                "Activity":activity,
                "Rating":rating,
                "Time_Spent":time_spent
            })
            
    return pd.DataFrame(user_data)
user_df = getUserData(data_new)
user_df.to_csv(r"Notebook/Interaction.csv")

# %%
user_df = pd.read_csv(r"Notebook/Interaction.csv")
user_df[user_df['User_ID'] == "User_01"]['Activity'].value_counts()
# Out:
# Activity
# buffet             2
# main_restaurant    2
# tennis_court       2
# pool               1
# beach_activity     1
# spa                1
# business_center    1
# city_tour          1
# golf               1
# gym                1
# yoga               1
# Name: count, dtype: int64

# %%
Activity_Ls = []
for i in activities:
    Activity_Ls+=activities[i]
Activity_Ls
# Out:
# ['pool',
#  'spa',
#  'gym',
#  'tennis_court',
#  'business_center',
#  'main_restaurant',
#  'cafe',
#  'bar',
#  'room_service',
#  'buffet',
#  'city_tour',
#  'beach_activity',
#  'cooking_class',
#  'yoga',
#  'golf']

# %%
rating_matrix = user_df.pivot_table(index='User_ID', columns="Activity", values="Rating").fillna(0)
rating_matrix
# Out:
# Activity     bar  beach_activity  buffet  business_center  cafe  city_tour  \
# User_ID
# User_01      0.0        5.000000     0.0         1.000000   1.0        0.0
# User_010     1.0        0.000000     1.0         0.000000   5.0        2.0
# User_0100    4.0        3.333333     0.0         3.000000   0.0        3.0
# User_01000   4.0        5.000000     0.0         0.000000   5.0        0.0
# User_010000  2.0        0.000000     0.0         0.000000   0.0        0.0
# ...          ...             ...     ...              ...   ...        ...
# User_09995   0.0        2.000000     1.0         1.833333   3.5        0.0
# User_09996   0.0        2.000000     0.0         0.000000   3.5        3.0
# User_09997   0.0        2.000000     0.0         4.000000   2.0        4.0
# User_09998   3.0        0.000000     0.0         2.333333   4.0        1.5
# User_09999   3.0        0.000000     0.0         0.000000   0.0        0.0
#
# Activity     cooking_class  golf  gym  main_restaurant      pool  \
# User_ID
# User_01                3.0   0.0  0.0              0.0  5.000000
# User_010               3.0   2.0  1.0              1.0  0.000000
# User_0100              0.0   3.0  5.0              0.0  0.000000
# User_01000             0.0   0.0  2.0              5.0  4.000000
# User_010000            1.0   3.0  1.0              2.0  3.000000
# ...                    ...   ...  ...              ...       ...
# User_09995             0.0   5.0  4.5              5.0  4.000000
# User_09996             0.0   0.0  5.0              2.0  0.000000
# User_09997             2.0   0.0  4.0              3.0  0.000000
# User_09998             3.0   0.0  5.0              0.0  2.333333
# User_09999             5.0   4.5  1.5              1.0  1.000000
#
# Activity     room_service  spa  tennis_court  yoga
# User_ID
# User_01          3.250000  0.0      0.000000   0.0
# User_010         4.000000  3.0      3.000000   2.5
# User_0100        4.000000  0.0      0.000000   0.0
# User_01000       0.000000  4.0      5.000000   2.0
# User_010000      3.000000  3.0      0.000000   3.0
# ...                   ...  ...           ...   ...
# User_09995       2.333333  0.0      2.000000   2.0
# User_09996       0.000000  2.5      2.000000   1.0
# User_09997       1.500000  4.0      5.000000   3.0
# User_09998       0.000000  3.0      2.666667   0.0
# User_09999       0.000000  4.0      0.000000   3.0
#
# [10000 rows x 15 columns]

# %%
def getSimilarUser(user_id, matrix, k = 3):
    user_data = matrix[matrix.index == user_id]
    other_user = matrix[matrix.index != user_id]

    similar_matrix = cosine_similarity(user_data, other_user)[0].tolist()
    user_indices = dict(zip(other_user.index, similar_matrix))
    similar_user = sorted(user_indices.items(), key = lambda x: x[1], reverse = True)

    top_similar_user = similar_user[:k]
    users = [u[0] for u in top_similar_user]
    return users

similar_user_indices = getSimilarUser("User_0100", rating_matrix)

# %%
def getRecommendations(user_id, matrix, similar_user_indices, k = 3):
    similar_users = matrix[matrix.index.isin(similar_user_indices)]
    similar_users = similar_users.mean(axis = 0)
    similar_users_df = pd.DataFrame(similar_users, columns = ['mean'])

    user_df = matrix[matrix.index == user_id].T
    user_df.columns = ['ratings']
    user_df = user_df[user_df['ratings'] == 0]

    unseen_data = user_df.index.tolist()
    similar_user_data = similar_users_df[similar_users_df.index.isin(unseen_data)].sort_values(by = 'mean', ascending = False)

    recommonded_activity = similar_user_data.head(k)

    return recommonded_activity.index.tolist()

getRecommendations("User_0100",rating_matrix, similar_user_indices)
# Out:
# ['spa', 'tennis_court', 'main_restaurant']

# %%
getRecommendations("User_01",rating_matrix, similar_user_indices)
# Out:
# ['gym', 'bar', 'golf']
